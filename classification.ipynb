# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction import DictVectorizer as DV
from sklearn.model_selection import GridSearchCV
from sklearn import feature_selection as fs
from sklearn.svm import LinearSVC
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Загрузим тренировочные и тестовые данные

# %%
test = pd.read_csv('orange_small_churn_test_data.csv')
train = pd.read_csv('orange_small_churn_data.txt')

train.shape, test.shape
# Out:
# ((40000, 230), (10000, 231))

# %%
test.drop(columns='ID', inplace=True)

# %% [markdown]
# Объединим выборки для дальнейшего рассмотрения.
# Удалим из рассмотрения признаки с нулевыми корреляциями.

# %%
data = pd.concat([train, test], axis=0)
data.shape
# Out:
# (50000, 230)

# %%
data.describe()
# Out:
#              Var1         Var2           Var3         Var4          Var5  \
# count  702.000000  1241.000000    1240.000000  1579.000000  1.487000e+03
# mean    11.487179     0.004029     425.298387     0.125396  2.387933e+05
# std     40.709951     0.141933    4270.193518     1.275481  6.441259e+05
# min      0.000000     0.000000       0.000000     0.000000  0.000000e+00
# 25%      0.000000     0.000000       0.000000     0.000000  0.000000e+00
# 50%      0.000000     0.000000       0.000000     0.000000  0.000000e+00
# 75%     16.000000     0.000000       0.000000     0.000000  1.187425e+05
# max    680.000000     5.000000  130668.000000    27.000000  6.048550e+06
#
#                 Var6          Var7  Var8         Var9         Var10  ...  \
# count   44471.000000  44461.000000   0.0   702.000000  1.487000e+03  ...
# mean     1326.437116      6.809496   NaN    48.145299  3.926057e+05  ...
# std      2685.693668      6.326053   NaN   154.777855  9.280896e+05  ...
# min         0.000000      0.000000   NaN     0.000000  0.000000e+00  ...
# 25%       518.000000      0.000000   NaN     4.000000  0.000000e+00  ...
# 50%       861.000000      7.000000   NaN    20.000000  0.000000e+00  ...
# 75%      1428.000000      7.000000   NaN    46.000000  2.628630e+05  ...
# max    131761.000000    140.000000   NaN  2300.000000  1.232559e+07  ...
#
#              Var183       Var184  Var185      Var186     Var187       Var188  \
# count  1.241000e+03  1241.000000     0.0  702.000000  702.00000  1241.000000
# mean   7.777380e+04     8.460919     NaN    3.299145   16.54416   167.368477
# std    2.016188e+05    46.973777     NaN    8.781967   60.22303   113.980072
# min    0.000000e+00     0.000000     NaN    0.000000    0.00000    -6.420000
# 25%    0.000000e+00     0.000000     NaN    0.000000    0.00000    19.380000
# 50%    0.000000e+00     0.000000     NaN    0.000000    4.00000   197.640000
# 75%    4.881000e+04     8.000000     NaN    6.000000   14.00000   252.960000
# max    3.048400e+06  1200.000000     NaN  102.000000  910.00000   628.620000
#
#              Var189         Var190  Var209  Var230
# count  21022.000000     333.000000     0.0     0.0
# mean     270.142137   22007.045192     NaN     NaN
# std       86.707692   29085.146490     NaN     NaN
# min        6.000000       0.000000     NaN     NaN
# 25%      204.000000    2732.670000     NaN     NaN
# 50%      270.000000   12668.940000     NaN     NaN
# 75%      330.000000   29396.340000     NaN     NaN
# max      642.000000  230427.000000     NaN     NaN
#
# [8 rows x 192 columns]

# %%
fts_null = ['Var209', 'Var230', 'Var31', 'Var167', 'Var32', 'Var175', 'Var15', 'Var39', 'Var185',
       'Var42', 'Var48', 'Var8', 'Var141', 'Var79', 'Var55', 'Var169', 'Var52',
       'Var20']

# %%
data = data.drop(columns=fts_null)
data.describe()
# Out:
#              Var1         Var2           Var3         Var4          Var5  \
# count  702.000000  1241.000000    1240.000000  1579.000000  1.487000e+03
# mean    11.487179     0.004029     425.298387     0.125396  2.387933e+05
# std     40.709951     0.141933    4270.193518     1.275481  6.441259e+05
# min      0.000000     0.000000       0.000000     0.000000  0.000000e+00
# 25%      0.000000     0.000000       0.000000     0.000000  0.000000e+00
# 50%      0.000000     0.000000       0.000000     0.000000  0.000000e+00
# 75%     16.000000     0.000000       0.000000     0.000000  1.187425e+05
# max    680.000000     5.000000  130668.000000    27.000000  6.048550e+06
#
#                 Var6          Var7         Var9         Var10        Var11  \
# count   44471.000000  44461.000000   702.000000  1.487000e+03  1240.000000
# mean     1326.437116      6.809496    48.145299  3.926057e+05     8.625806
# std      2685.693668      6.326053   154.777855  9.280896e+05     2.869558
# min         0.000000      0.000000     0.000000  0.000000e+00     8.000000
# 25%       518.000000      0.000000     4.000000  0.000000e+00     8.000000
# 50%       861.000000      7.000000    20.000000  0.000000e+00     8.000000
# 75%      1428.000000      7.000000    46.000000  2.628630e+05     8.000000
# max    131761.000000    140.000000  2300.000000  1.232559e+07    40.000000
#
#        ...        Var180        Var181        Var182        Var183  \
# count  ...  7.020000e+02  44991.000000  1.579000e+03  1.241000e+03
# mean   ...  3.776755e+06      0.611456  1.416638e+06  7.777380e+04
# std    ...  3.785696e+06      2.495681  2.279786e+06  2.016188e+05
# min    ...  0.000000e+00      0.000000  0.000000e+00  0.000000e+00
# 25%    ...  1.917352e+05      0.000000  0.000000e+00  0.000000e+00
# 50%    ...  2.431310e+06      0.000000  1.167780e+05  0.000000e+00
# 75%    ...  6.471827e+06      0.000000  1.844952e+06  4.881000e+04
# max    ...  1.428483e+07     49.000000  1.199478e+07  3.048400e+06
#
#             Var184      Var186     Var187       Var188        Var189  \
# count  1241.000000  702.000000  702.00000  1241.000000  21022.000000
# mean      8.460919    3.299145   16.54416   167.368477    270.142137
# std      46.973777    8.781967   60.22303   113.980072     86.707692
# min       0.000000    0.000000    0.00000    -6.420000      6.000000
# 25%       0.000000    0.000000    0.00000    19.380000    204.000000
# 50%       0.000000    0.000000    4.00000   197.640000    270.000000
# 75%       8.000000    6.000000   14.00000   252.960000    330.000000
# max    1200.000000  102.000000  910.00000   628.620000    642.000000
#
#               Var190
# count     333.000000
# mean    22007.045192
# std     29085.146490
# min         0.000000
# 25%      2732.670000
# 50%     12668.940000
# 75%     29396.340000
# max    230427.000000
#
# [8 rows x 174 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 9999
# Columns: 212 entries, Var1 to Var229
# dtypes: float64(173), int64(1), object(38)
# memory usage: 81.3+ MB

# %% [markdown]
# Выделим числовые и категорийные признаки

# %%
data_num = data.ix[:, :'Var190']
data_cat = data.ix[:,'Var191':]

# %%
data_num.describe()
# Out:
#              Var1         Var2           Var3         Var4          Var5  \
# count  702.000000  1241.000000    1240.000000  1579.000000  1.487000e+03
# mean    11.487179     0.004029     425.298387     0.125396  2.387933e+05
# std     40.709951     0.141933    4270.193518     1.275481  6.441259e+05
# min      0.000000     0.000000       0.000000     0.000000  0.000000e+00
# 25%      0.000000     0.000000       0.000000     0.000000  0.000000e+00
# 50%      0.000000     0.000000       0.000000     0.000000  0.000000e+00
# 75%     16.000000     0.000000       0.000000     0.000000  1.187425e+05
# max    680.000000     5.000000  130668.000000    27.000000  6.048550e+06
#
#                 Var6          Var7         Var9         Var10        Var11  \
# count   44471.000000  44461.000000   702.000000  1.487000e+03  1240.000000
# mean     1326.437116      6.809496    48.145299  3.926057e+05     8.625806
# std      2685.693668      6.326053   154.777855  9.280896e+05     2.869558
# min         0.000000      0.000000     0.000000  0.000000e+00     8.000000
# 25%       518.000000      0.000000     4.000000  0.000000e+00     8.000000
# 50%       861.000000      7.000000    20.000000  0.000000e+00     8.000000
# 75%      1428.000000      7.000000    46.000000  2.628630e+05     8.000000
# max    131761.000000    140.000000  2300.000000  1.232559e+07    40.000000
#
#        ...        Var180        Var181        Var182        Var183  \
# count  ...  7.020000e+02  44991.000000  1.579000e+03  1.241000e+03
# mean   ...  3.776755e+06      0.611456  1.416638e+06  7.777380e+04
# std    ...  3.785696e+06      2.495681  2.279786e+06  2.016188e+05
# min    ...  0.000000e+00      0.000000  0.000000e+00  0.000000e+00
# 25%    ...  1.917352e+05      0.000000  0.000000e+00  0.000000e+00
# 50%    ...  2.431310e+06      0.000000  1.167780e+05  0.000000e+00
# 75%    ...  6.471827e+06      0.000000  1.844952e+06  4.881000e+04
# max    ...  1.428483e+07     49.000000  1.199478e+07  3.048400e+06
#
#             Var184      Var186     Var187       Var188        Var189  \
# count  1241.000000  702.000000  702.00000  1241.000000  21022.000000
# mean      8.460919    3.299145   16.54416   167.368477    270.142137
# std      46.973777    8.781967   60.22303   113.980072     86.707692
# min       0.000000    0.000000    0.00000    -6.420000      6.000000
# 25%       0.000000    0.000000    0.00000    19.380000    204.000000
# 50%       0.000000    0.000000    4.00000   197.640000    270.000000
# 75%       8.000000    6.000000   14.00000   252.960000    330.000000
# max    1200.000000  102.000000  910.00000   628.620000    642.000000
#
#               Var190
# count     333.000000
# mean    22007.045192
# std     29085.146490
# min         0.000000
# 25%      2732.670000
# 50%     12668.940000
# 75%     29396.340000
# max    230427.000000
#
# [8 rows x 174 columns]

# %%
data_cat.describe()
# Out:
#        Var191      Var192 Var193 Var194 Var195 Var196 Var197   Var198  \
# count    1083       49631  50000  12784  50000  50000  49857    50000
# unique      1         361     51      3     23      4    225     4291
# top      r__I  qFpmfo8zhV   RO12   SEuy   taul   1K8T   0Xwj  fhk21Ss
# freq     1083         385  35964  12567  47958  49550   4629     4441
#
#          Var199   Var200  ...   Var220 Var221   Var222      Var223 Var224  \
# count     49996    24592  ...    50000  50000    50000       44789    820
# unique     5073    15415  ...     4291      7     4291           4      1
# top     r83_sZi  yP09M03  ...  4UxGlow   oslk  catzS2D  LM8l689qOp   4n2X
# freq        955       73  ...     4441  37009     4441       36608    820
#
#        Var225 Var226 Var227         Var228 Var229
# count   23856  50000  50000          50000  21568
# unique      3     23      7             30      4
# top      ELof   FSa2   RAYp  F2FyR07IdsN7I   am7c
# freq    11072   8031  35156          32703  11689
#
# [4 rows x 38 columns]

# %% [markdown]
# В категорийных пропуски заменим на "0"

# %%
data_cat.fillna('0', inplace=True)

# %% [markdown]
# закодируем категорийные признаки. в задаче baseline было установлено, что кодировать лучше в числа.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data_cat_le = pd.DataFrame()
for i in data_cat.columns:
    le = LabelEncoder()
    le.fit(data_cat[i])
    data_cat_le[i] = le.transform(data_cat[i])
    
data_cat_le.describe()
# Out:
#              Var191        Var192        Var193        Var194        Var195  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.021660    173.853300     20.994300      0.514060     21.508480
# std        0.145572    107.065246     10.322155      0.879555      2.588865
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000     82.000000     25.000000      0.000000     22.000000
# 50%        0.000000    165.000000     25.000000      0.000000     22.000000
# 75%        0.000000    266.000000     25.000000      2.000000     22.000000
# max        1.000000    361.000000     50.000000      3.000000     22.000000
#
#             Var196        Var197       Var198        Var199        Var200  \
# count  50000.00000  50000.000000  50000.00000  50000.000000  50000.000000
# mean       0.02630    103.600760   2223.29334   2498.148400   3788.870820
# std        0.27837     71.634777   1197.29489   1381.535728   4962.391785
# min        0.00000      0.000000      0.00000      0.000000      0.000000
# 25%        0.00000     29.000000   1187.00000   1292.000000      0.000000
# 50%        0.00000    110.000000   2435.00000   2456.500000      0.000000
# 75%        0.00000    178.000000   3119.00000   3697.000000   7574.250000
# max        3.00000    225.000000   4290.00000   5073.000000  15415.000000
#
#        ...       Var220        Var221        Var222        Var223  \
# count  ...  50000.00000  50000.000000  50000.000000  50000.000000
# mean   ...   2003.12184      3.984080   2123.702060      1.302480
# std    ...   1248.04682      1.119166   1183.541455      1.070238
# min    ...      0.00000      0.000000      0.000000      0.000000
# 25%    ...    826.00000      4.000000   1066.000000      1.000000
# 50%    ...   2014.00000      4.000000   2230.000000      1.000000
# 75%    ...   3047.00000      4.000000   2984.250000      1.000000
# max    ...   4290.00000      6.000000   4290.000000      4.000000
#
#              Var224        Var225        Var226        Var227        Var228  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.016400      0.779900     10.115720      2.103060     10.233400
# std        0.127009      0.933506      5.798438      0.867994      6.488254
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      6.000000      2.000000      8.000000
# 50%        0.000000      0.000000     10.000000      2.000000      8.000000
# 75%        0.000000      2.000000     14.000000      2.000000      8.000000
# max        1.000000      3.000000     22.000000      6.000000     29.000000
#
#              Var229
# count  50000.000000
# mean       0.631200
# std        0.799074
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        4.000000
#
# [8 rows x 38 columns]

# %%
data_num.head()
# Out:
#    Var1  Var2  Var3  Var4  Var5    Var6  Var7  Var9  Var10  Var11  ...  \
# 0   NaN   NaN   NaN   NaN   NaN  3052.0   NaN   NaN    NaN    NaN  ...
# 1   NaN   NaN   NaN   NaN   NaN  1813.0   7.0   NaN    NaN    NaN  ...
# 2   NaN   NaN   NaN   NaN   NaN  1953.0   7.0   NaN    NaN    NaN  ...
# 3   NaN   NaN   NaN   NaN   NaN  1533.0   7.0   NaN    NaN    NaN  ...
# 4   NaN   NaN   NaN   NaN   NaN   686.0   7.0   NaN    NaN    NaN  ...
#
#    Var180  Var181  Var182  Var183  Var184  Var186  Var187  Var188  Var189  \
# 0     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN   276.0
# 2     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Var190
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#
# [5 rows x 174 columns]

# %% [markdown]
# Пропуски в числовых признаках заменим на среднее

# %%
for i in data_num.columns:
    current_mean = data_num.ix[:, i].mean()
    data_num.ix[:, i].fillna(current_mean, inplace=True)

# %%
data_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 9999
# Columns: 174 entries, Var1 to Var190
# dtypes: float64(173), int64(1)
# memory usage: 66.8 MB

# %% [markdown]
# объединим датафрейм с закодированными данными

# %%
data_1 = pd.DataFrame(np.hstack((data_num, data_cat_le)), columns=data.columns)
data_1.shape
# Out:
# (50000, 212)

# %%
data_1.head()
# Out:
#         Var1      Var2        Var3      Var4          Var5    Var6      Var7  \
# 0  11.487179  0.004029  425.298387  0.125396  238793.32885  3052.0  6.809496
# 1  11.487179  0.004029  425.298387  0.125396  238793.32885  1813.0  7.000000
# 2  11.487179  0.004029  425.298387  0.125396  238793.32885  1953.0  7.000000
# 3  11.487179  0.004029  425.298387  0.125396  238793.32885  1533.0  7.000000
# 4  11.487179  0.004029  425.298387  0.125396  238793.32885   686.0  7.000000
#
#         Var9          Var10     Var11  ...  Var220  Var221  Var222  Var223  \
# 0  48.145299  392605.656355  8.625806  ...  3129.0     0.0  4067.0     1.0
# 1  48.145299  392605.656355  8.625806  ...  3138.0     4.0   379.0     1.0
# 2  48.145299  392605.656355  8.625806  ...   350.0     6.0  2751.0     1.0
# 3  48.145299  392605.656355  8.625806  ...  4232.0     4.0  2864.0     1.0
# 4  48.145299  392605.656355  8.625806  ...  1797.0     4.0  1506.0     1.0
#
#    Var224  Var225  Var226  Var227  Var228  Var229
# 0     0.0     0.0    14.0     0.0    29.0     0.0
# 1     0.0     1.0    22.0     2.0     2.0     2.0
# 2     0.0     0.0     7.0     3.0    25.0     2.0
# 3     0.0     0.0    22.0     2.0     8.0     0.0
# 4     0.0     0.0    12.0     2.0     8.0     0.0
#
# [5 rows x 212 columns]

# %%
data_1.describe()
# Out:
#                Var1          Var2           Var3          Var4          Var5  \
# count  50000.000000  50000.000000   50000.000000  50000.000000  5.000000e+04
# mean      11.487179      0.004029     425.298387      0.125396  2.387933e+05
# std        4.820354      0.022352     672.206258      0.226593  1.110451e+05
# min        0.000000      0.000000       0.000000      0.000000  0.000000e+00
# 25%       11.487179      0.004029     425.298387      0.125396  2.387933e+05
# 50%       11.487179      0.004029     425.298387      0.125396  2.387933e+05
# 75%       11.487179      0.004029     425.298387      0.125396  2.387933e+05
# max      680.000000      5.000000  130668.000000     27.000000  6.048550e+06
#
#                 Var6          Var7          Var9         Var10         Var11  \
# count   50000.000000  50000.000000  50000.000000  5.000000e+04  50000.000000
# mean     1326.437116      6.809496     48.145299  3.926057e+05      8.625806
# std      2532.849475      5.965363     18.326822  1.599995e+05      0.451721
# min         0.000000      0.000000      0.000000  0.000000e+00      8.000000
# 25%       581.000000      0.000000     48.145299  3.926057e+05      8.625806
# 50%       945.000000      7.000000     48.145299  3.926057e+05      8.625806
# 75%      1326.437116      7.000000     48.145299  3.926057e+05      8.625806
# max    131761.000000    140.000000   2300.000000  1.232559e+07     40.000000
#
#        ...       Var220        Var221        Var222        Var223  \
# count  ...  50000.00000  50000.000000  50000.000000  50000.000000
# mean   ...   2003.12184      3.984080   2123.702060      1.302480
# std    ...   1248.04682      1.119166   1183.541455      1.070238
# min    ...      0.00000      0.000000      0.000000      0.000000
# 25%    ...    826.00000      4.000000   1066.000000      1.000000
# 50%    ...   2014.00000      4.000000   2230.000000      1.000000
# 75%    ...   3047.00000      4.000000   2984.250000      1.000000
# max    ...   4290.00000      6.000000   4290.000000      4.000000
#
#              Var224        Var225        Var226        Var227        Var228  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.016400      0.779900     10.115720      2.103060     10.233400
# std        0.127009      0.933506      5.798438      0.867994      6.488254
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      6.000000      2.000000      8.000000
# 50%        0.000000      0.000000     10.000000      2.000000      8.000000
# 75%        0.000000      2.000000     14.000000      2.000000      8.000000
# max        1.000000      3.000000     22.000000      6.000000     29.000000
#
#              Var229
# count  50000.000000
# mean       0.631200
# std        0.799074
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        4.000000
#
# [8 rows x 212 columns]

# %% [markdown]
# Вернем разбиение train и test

# %%
train = data_1.ix[:39999, :]
test = data_1.ix[40000:, :]
train.shape, test.shape
# Out:
# ((40000, 212), (10000, 212))

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Columns: 212 entries, Var1 to Var229
# dtypes: float64(212)
# memory usage: 64.7 MB

# %%
labels = pd.read_csv('orange_small_churn_labels.txt', header=None)

# %%
labels.head()
# Out:
#    0
# 0 -1
# 1 -1
# 2 -1
# 3  1
# 4 -1

# %% [markdown]
# Сократим количество признаков

# %%
from sklearn.svm import LinearSVC

# %%
sfm = fs.SelectFromModel(LinearSVC(penalty="l1", dual=False))
X = sfm.fit_transform(train, labels)
X.shape
# Out:
# (40000, 142)

# %% [markdown]
# Импортируем нужные нам модели

# %%
from sklearn.linear_model import RidgeClassifier as RC
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.ensemble import GradientBoostingClassifier as GBS
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import StratifiedKFold
from sklearn import metrics

# %% [markdown]
# В задании baseline установили, что для кросс-валидации лучше использовать StratifiedKFold

# %%
cross_val = StratifiedKFold(n_splits=3, random_state=13)

# %% [markdown]
# Из метрик качества оставим только AUC-PRC. И посмотрим все модели.

# %%
rc = RC(random_state=13)
rfc = RFC(random_state=13)
gbs = GBS(random_state=13)
estimators = [rc, rfc, gbs]
current_score = []
for estim in estimators:
    print('Текущая модель', estim)
    current = cross_val_score(estim, train, labels, scoring = 'average_precision', cv = cross_val)
    current_score.append(current.mean())
# Out:
# Текущая модель RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#         max_iter=None, normalize=False, random_state=13, solver='auto',
#         tol=0.001)
# Текущая модель RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=13, verbose=0, warm_start=False)
# Текущая модель GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=13,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)

# %%
current_score
# Out:
# [0.14061107703966044, 0.10241796924644964, 0.19779511460025848]

# %% [markdown]
# Как видим, лучший результат у GradientBoostingClassifier. Оставим эту модель для дальнейшего рассмотрения

# %%
parameters={"max_depth": [5, 10, 15],
    'min_samples_leaf' : [1, 4, 5, 7, 10],
    'n_estimators' : [100, 200, 300]}

# %%
mod = GridSearchCV(GBS(random_state=13), param_grid=parameters, scoring='average_precision', cv=cross_val, n_jobs=-1)
# %time mod.fit(X, labels)
# Out:
# CPU times: user 42.9 s, sys: 466 ms, total: 43.4 s
# Wall time: 2h 14min 50s
# GridSearchCV(cv=StratifiedKFold(n_splits=3, random_state=13, shuffle=False),
#        error_score='raise-deprecating',
#        estimator=GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_sampl...      subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'max_depth': [5, 10, 15], 'min_samples_leaf': [1, 4, 5, 7, 10], 'n_estimators': [100, 200, 300]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='average_precision', verbose=0)

# %%
print( mod.best_score_)
print (mod.best_params_)
# Out:
# 0.21119003630683114
# {'max_depth': 5, 'min_samples_leaf': 10, 'n_estimators': 100}

# %%
final_model = GBS(max_depth=5, n_estimators=100, min_samples_leaf=7, random_state=13)
final_model.fit(X, labels)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=5,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=7, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=13,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)

# %% [markdown]
# Расчитаем ROC-AUC

# %%
cross_val_score(final_model, X, labels, scoring = metrics.scorer.roc_auc_scorer, cv = cross_val).mean()
# Out:
# 0.7282572781076097

# %% [markdown]
# Сократим количество признаков у тестовых данных и сделаем прогноз

# %%
test = test.ix[:, sfm.get_support()]
test.shape
# Out:
# (10000, 142)

# %%
result = final_model.predict_proba(test)

# %%
res_data = pd.DataFrame()
res_data.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
res_data['ID'] = range(len(result))
res_data['result'] = result[:,1]

# %%
res_data.head()
# Out:
#    ID    result
# 0   0  0.084701
# 1   1  0.117179
# 2   2  0.027984
# 3   3  0.071522
# 4   4  0.015797

# %%
res_data.to_csv('result6.csv', index=False)

# %% [markdown]
# Конечный результат: 0.71435
